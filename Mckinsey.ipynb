# %% [markdown]
# <a href="https://colab.research.google.com/github/Vibrant-Oracle/Python_Examples/blob/main/Mckinsey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/McKinsey.csv")

# %%
df.head()
# Out:
#   Testtaker ID  Country                     Region      Gender  Age  Year  \
# 0      MCK0001   Turkey                     Europe  Non-Binary   24  2024
# 1      MCK0002  Hungary                     Europe      Female   27  2021
# 2      MCK0003  Finland                     Europe        Male   25  2018
# 3      MCK0004  Finland                     Europe  Non-Binary   20  2020
# 4      MCK0005    Chile  Central and South America  Non-Binary   25  2021
#
#   Highest Level of Education           School/University  \
# 0                    Masters        Bilkent University
# 1                    Masters  Eötvös Loránd University
# 2              Undergraduate    University of Helsinki
# 3              Undergraduate          Aalto University
# 4              Undergraduate      Universidad de Chile
#
#   First-generation university Employment Status  ... Time Spent on Ecosystem  \
# 0                          No          Employed  ...                      16
# ...

# %%
df.shape
# Out:
# (4000, 26)

# %%
df.columns # or df.keys()
# Out:
# Index(['Testtaker ID', 'Country', 'Region', 'Gender', 'Age', 'Year',
#        'Highest Level of Education', 'School/University',
#        'First-generation university', 'Employment Status', 'Role Applied',
#        'Department / Interest', 'Past Test Taker',
#        'Prepared with Online Materials', 'Desired Office', 'Ecosystem %',
#        'Time Spent on Ecosystem', 'Redrock %', 'Time Spent on Redrock',
#        'Seawolf %', 'Time Spent on Seawolf', 'Total Product Score',
#        'Process Score', 'Resume Score', 'Total Assessment Score', 'Status'],
#       dtype='object')

# %%
 df.keys()
# Out:
# Index(['Testtaker ID', 'Country', 'Region', 'Gender', 'Age', 'Year',
#        'Highest Level of Education', 'School/University',
#        'First-generation university', 'Employment Status', 'Role Applied',
#        'Department / Interest', 'Past Test Taker',
#        'Prepared with Online Materials', 'Desired Office', 'Ecosystem %',
#        'Time Spent on Ecosystem', 'Redrock %', 'Time Spent on Redrock',
#        'Seawolf %', 'Time Spent on Seawolf', 'Total Product Score',
#        'Process Score', 'Resume Score', 'Total Assessment Score', 'Status'],
#       dtype='object')

# %%
df["Country"]
# Out:
# 0               Turkey
# 1              Hungary
# 2              Finland
# 3              Finland
# 4                Chile
#              ...
# 3995    United Kingdom
# 3996            Brazil
# 3997     United States
# 3998       New Zealand
# 3999      South Africa
# Name: Country, Length: 4000, dtype: object

# %%
df["Country"].unique()
# Out:
# array(['Turkey', 'Hungary', 'Finland', 'Chile', 'Sweden', 'Germany',
#        'Panama', 'Norway', 'Bahrain', 'South Africa', 'Pakistan',
#        'Angola', 'Vietnam', 'Costa Rica', 'Malaysia', 'Egypt',
#        'Greater China', 'United Kingdom', 'Ecuador',
#        'United Arab Emirates', 'Nigeria', 'Kenya', 'Netherlands',
#        'Sri Lanka', 'Spain', 'Switzerland', 'Austria', 'Czech Republic',
#        'Dominican Republic', 'Philippines', 'Romania', 'United States',
#        'Azerbaijan', 'Portugal', 'Indonesia', 'Ireland', 'Greece',
#        'Thailand', 'Israel', 'Brazil', 'Mexico', 'Peru', 'Kuwait',
#        'Colombia', 'Italy', 'Morocco', 'France', 'Croatia', 'Japan',
#        'Poland', 'Singapore', 'Ethiopia', 'Ukraine', 'Saudi Arabia',
#        'South Korea', 'New Zealand', 'Guatemala', 'Qatar', 'India',
#        'Denmark', 'Australia', 'Canada', 'Luxembourg', 'Argentina',
#        'Belgium', 'Uruguay', 'Kazakhstan'], dtype=object)

# %%
df["Country"].nunique()
# Out:
# 67

# %%
df["Country"].value_counts()
# Out:
# Country
# United States     177
# United Kingdom    139
# Nigeria            89
# Egypt              87
# South Korea        76
#                  ...
# Belgium            44
# Greece             43
# Japan              42
# Ukraine            37
# Uruguay            28
# Name: count, Length: 67, dtype: int64

# %%
df.rename({"country":"Country", "year":"Year"},axis=1 , inplace=True)
